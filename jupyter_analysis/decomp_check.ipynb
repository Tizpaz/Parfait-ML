# %%
import pandas as pd

# %%
data = pd.read_csv("../subjects/datasets/census")

# %%
X = data.drop('label', 1)
X
# Out:
# /tmp/ipykernel_15368/1819788139.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X = data.drop('label', 1)
#        a  b   c  d  e  f  g  race  sex   j  k   l   m
# 0      3  5   3  0  2  8  3     0    1   2  0  40   0
# 1      5  1   4  0  0  4  2     0    1   0  0  13   0
# 2      3  0  10  3  1  6  3     0    1   0  0  40   0
# 3      5  0  11  2  0  6  2     4    1   0  0  40   0
# 4      2  0  16  0  0  5  0     4    0   0  0  40  12
# ...   .. ..  .. .. .. .. ..   ...  ...  .. ..  ..  ..
# 32556  2  0  12  5  0  0  0     0    0   0  0  38   0
# 32557  4  0   7  3  0  7  2     0    1   0  0  40   0
# 32558  5  0   7  3  4  8  5     0    0   0  0  40   0
# 32559  2  0  10  3  2  8  1     0    1   0  0  20   0
# 32560  5  2  14  3  0  4  0     0    0  15  0  40   0
#
# [32561 rows x 13 columns]

# %%
from sklearn.decomposition import PCA, FastICA
from sklearn.preprocessing import StandardScaler

# %%
X_scaled = StandardScaler().fit_transform(X)
pca = PCA()
pca.fit(X)
# Out:
# PCA()

# %%
pca.explained_variance_
# Out:
# array([1.01854630e+03, 2.01783125e+02, 1.48211100e+02, 5.28246806e+01,
#        2.79367589e+01, 1.53967865e+01, 1.18939821e+01, 5.66114738e+00,
#        2.10851883e+00, 1.99039885e+00, 1.34893440e+00, 7.40246663e-01,
#        1.78578677e-01])

# %%
pca.components_
# Out:
# array([[ 1.94478327e-03,  7.16689208e-01, -4.97379506e-04,
#          2.53943320e-03,  3.14001822e-03,  6.93301246e-01,
#         -1.74399417e-03,  9.95701595e-04, -1.09950904e-03,
#         -4.38880903e-03, -2.18358610e-03, -7.49133050e-02,
#         -5.32432627e-03],
#        [-1.03425054e-03,  4.70730990e-03,  1.83799254e-02,
#          2.09775762e-02,  1.99550182e-03,  3.84488353e-03,
#          2.10572335e-03,  5.56716776e-03,  4.89314495e-04,
#          4.62251924e-03,  6.34410841e-04,  9.95361913e-03,
#          9.99511688e-01],
#        [ 9.67689355e-03,  5.04783215e-02, -1.06911457e-02,
#          4.37205403e-03, -2.08917543e-02,  5.57285718e-02,
#          4.77651498e-03, -5.27646533e-03,  8.54228451e-03,
#          7.09081935e-02,  1.80155929e-02,  9.94030149e-01,
#         -1.05188024e-02],
#        [ 1.31594518e-02,  4.23371779e-03,  3.86986737e-03,
#          1.11193144e-02, -8.04018069e-03, -5.88748420e-03,
#         -5.83372501e-03, -2.33600893e-03,  1.39639394e-03,
# ...

# %%
pca = PCA()
pca.fit(X_scaled)
# Out:
# PCA()

# %%
pca.components_
# Out:
# array([[-4.47680561e-02,  6.04774530e-01,  1.57303171e-02,
#          8.39951120e-03,  2.84303198e-01,  6.06018329e-01,
#          7.95451397e-02,  1.14255109e-01, -2.59796208e-01,
#         -7.20016101e-02, -6.30843416e-02, -2.96308243e-01,
#          9.49670687e-04],
#        [ 2.40669146e-01,  3.29221897e-01, -7.42537881e-02,
#          6.79003071e-02, -5.22834510e-01,  3.25043235e-01,
#         -3.81168433e-01, -2.40123765e-01,  4.25693869e-01,
#          1.24029834e-01,  1.09708688e-01,  1.74902065e-01,
#         -4.88262647e-02],
#        [ 5.65950757e-01,  4.04615646e-02, -4.72413083e-03,
#          4.40657636e-01,  4.66725120e-02,  3.81968783e-02,
#          5.23207174e-01,  1.98543329e-01,  2.41375172e-02,
#          1.91968129e-01,  9.63135226e-02,  2.61648258e-01,
#          2.27789639e-01],
#        [-2.73910283e-01,  1.37774802e-02,  6.36217499e-01,
#          2.02221812e-01, -8.47061214e-02,  1.64796247e-02,
#         -2.14841089e-01,  3.64019475e-01,  1.94031449e-01,
# ...
